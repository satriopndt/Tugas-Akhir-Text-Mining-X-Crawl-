# %%
# !curl -sl https://deb.nodesource.com/setup_20.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# 2024-06-22 05:33:46 - Installing pre-requisites
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://deb.nodesource.com/node_20.x nodistro InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 257 kB in 6s (46.3 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# ...

# %%
data = "Marvel.csv"
search_keyword = "marvel lang:en"
limit = 600

# !npx --yes tweet-harvest@latest -o "{data}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import FuncFormatter

# %%
df = pd.read_csv('tweets-data/Marvel.csv', sep=',', on_bad_lines='warn')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 619 entries, 0 to 618
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      619 non-null    int64
#  1   created_at               619 non-null    object
#  2   favorite_count           619 non-null    int64
#  3   full_text                619 non-null    object
#  4   id_str                   619 non-null    int64
#  5   image_url                612 non-null    object
#  6   in_reply_to_screen_name  13 non-null     object
#  7   lang                     619 non-null    object
#  8   location                 434 non-null    object
#  9   quote_count              619 non-null    int64
#  10  reply_count              619 non-null    int64
#  11  retweet_count            619 non-null    int64
#  12  tweet_url                619 non-null    object
#  13  user_id_str              619 non-null    int64
# ...

# %%
df
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1804386848753557862  Sat Jun 22 05:32:03 +0000 2024            2323
# 1    1801713839496695814  Fri Jun 14 20:30:28 +0000 2024            1204
# 2    1801931963055358400  Sat Jun 15 10:57:12 +0000 2024            9164
# 3    1804178276560388201  Fri Jun 21 15:43:15 +0000 2024            1161
# 4    1803986539166282101  Fri Jun 21 03:01:22 +0000 2024           20485
# ..                   ...                             ...             ...
# 614  1801268197125197846  Thu Jun 13 14:59:38 +0000 2024               4
# 615  1801369423682338998  Thu Jun 13 21:41:53 +0000 2024               3
# 616  1801263039892566444  Thu Jun 13 15:05:53 +0000 2024              11
# 617  1801359798895788290  Thu Jun 13 21:03:38 +0000 2024              18
# 618  1717504497423917293  Thu Oct 26 11:32:36 +0000 2023           25181
#
#                                              full_text               id_str  \
# ...

# %%
import re
def remove_html(text):
  text = text.replace("\n", " ")
  pattern = re.compile('<.*?>')
  return pattern.sub(r'', text)

# %%
def remove_link(text):
  url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
  text = re.sub(url_pattern, '', text)
  return text

# %%
def replace_other_chars(text):
  pattern = re.compile(r'[()!@&;\/]')
  text = pattern.sub(r'', text)
  return text

# %%
def clean_text(text):
  text = remove_link(text)
  text = remove_html(text)
  text = replace_other_chars(text)
  return text
